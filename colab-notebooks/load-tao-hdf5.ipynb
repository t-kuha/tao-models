m2xly%2F2zB2z%2Frca673SDQw4sen2JvoWDZWYC5EmB3NXjCmlWubONtjeiLphzDhu6toXqEDs9y%2F1AwfPHW71e6r%2FmYcy1BzaJ4R4rozY9szh%2Bu6afeZ9kV4nAczNHGGvwnWeHUCifDbv8BRQMJ0L2eWYBtfHyfy24EJQM0hNbz8qVZn0tDpNkSQhWmCAuNrrsYAYr0jSABxisWBSWjqoHf8xt97BVDS6FqlxP9hfPbtYWmbJRBtQ%2B8fqHEkyFMZru7L9SYvisL69Vd0QoqTaau8uDyfX%2BtUP6lX1cQZscwldZAMN%2FPwo%2F1fwgRvw133moAmdBsbZq4yCLd32qRdk4WbwUB%2FIa3X8Gri0%2Bdn4ufzxAvG021Tp61BHRLFkpC8PhmK%2FAQuG2pm2uCtauwlC7tdjua3Y5CUkowTx0d7UQ1z4wugRGkIhyJz8Nsx72&kid=bXJrLWU3OGM1M2FhZjE4YzRiNmJiNjlkYmRhZjcxNjA3YWEw&ssec-enabled=true&Expires=1767615812&Signature=nOFm~cR8JdNagzsEWTl4gA02NEbtidBObvUsYbIeTwHVjBh7cn79ZWv66udZhQYxepc3~hh~BJKTK3DOXCdYcdBWZubynCPwwdQcOf9l1Z2NcTTcAnmC04~YhkiVWzCL2AcsZygh~WfFnEnMogcz3ZACGsMrzh-RomAq00yw4KlA90oaqaWy-sRAhoTuKTADXJw7afxHM3l986Zkc-bkuRTdbdld2ehzEVMaex6Zgks9A2XOgqiLOuY9lUoYmcA0JapzLUgW9c0saiysqGD~rnYzQQDSdyjQkeiP2y5251-HfLwZDIXtqOuaB--WG56kJmoaRAyOZ7H7i2La~SM1sw__&Key-Pair-Id=KCX06E8E9L60W
# Resolving xfiles.ngc.nvidia.com (xfiles.ngc.nvidia.com)... 13.35.37.15, 13.35.37.71, 13.35.37.90, ...
# Connecting to xfiles.ngc.nvidia.com (xfiles.ngc.nvidia.com)|13.35.37.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 93278448 (89M) [application/x-zerosize]
# Saving to: ‘resnet_18.hdf5’
#
# resnet_18.hdf5      100%[===================>]  88.96M   192MB/s    in 0.5s
#
# 2026-01-04 12:23:32 (192 MB/s) - ‘resnet_18.hdf5’ saved [93278448/93278448]

# %%
# import os
# os.environ["TF_USE_LEGACY_KERAS"] = "1"

import tensorflow as tf

print(f'{tf.__version__ = :}')
print(f'CPUs: {tf.config.list_physical_devices("CPU")}')
print(f'GPUs: {tf.config.list_physical_devices("GPU")}')
# print(tf.keras.version())  # Non-legacy Keras
# Out:
# tf.__version__ = 2.19.0
# CPUs: [PhysicalDevice(name='/physical_device:CPU:0', device_type='CPU')]
# GPUs: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
# tf.keras.backend.set_image_data_format('channels_first')
# tf.keras.backend.set_image_data_format('channels_last')

model = tf.keras.models.load_model("resnet_18.hdf5", compile=False)
# model.summary()

# %%
# dummy input
img = tf.ones((224, 224, 3), dtype=tf.uint8)

# apply pre-processing
preprocessed = tf.keras.applications.resnet50.preprocess_input(tf.cast(img, tf.float32))
preprocessed = tf.transpose(preprocessed, [2, 0, 1])

# run inference
pred = model.predict(tf.expand_dims(preprocessed, 0))
print(tf.argmax(pred, axis=1))

# model.save('resnet_18.keras')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# tf.Tensor([43], shape=(1,), dtype=int64)

# %% [markdown]
# ***
